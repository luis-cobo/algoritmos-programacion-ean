# %% [markdown]
# # Instrucciones Condicionales Complejas
#
# Ya sabemos que el lenguaje Python ofrece la instrucción `if` para la creación de flujos alternativos en el programa. Ahora vamos a conocer la manera de poder llevar a cabo acciones más complejas usando esta instrucción.
#
# ![](./Figura0504.jpg)

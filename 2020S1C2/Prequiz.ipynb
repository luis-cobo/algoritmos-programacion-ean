# %% [markdown]
# <h1 align="Center">Ejercicio en Clase PreQuiz<h1>
#
# Nombre Completo Estudiante:

# %% [markdown]
# ---
#
# # Ejercicio 1
#
# Escriba el modelaje y una función en Python que halle el área del círculo a partir del radio del mismo.

# %% [markdown]
# ## Modelaje
#
# _Datos de Entrada_
#
# Nombre | Identificador | Tipo
# -------| --------------|------
#
# _Datos de Salida_
#
# Nombre | Identificador | Tipo
# -------| --------------|------

# %%
# Aquí va la función

# %% [markdown]
# ---
#
# # Ejercicio 2
#
# Desarrolle el modelaje y una función en python que encuentre el área de la zona sombreada en la siguiente figura.
#
# ![Ejercicio](https://github.com/luis-cobo/algoritmos-programacion-ean/raw/master/imagenes/zonasombreada.png)
#
# donde $d$ es el diámetro del círculo pequeño y $D$ es el diámetro del círculo grande.**OBLIGATORIO: Usar la función anterior**.

# %% [markdown]
# ## Modelaje
#
# _Datos de Entrada_
#
# Nombre | Identificador | Tipo
# -------| --------------|------
#
# _Datos de Salida_
#
# Nombre | Identificador | Tipo
# -------| --------------|------

# %%
# Aquí va la función en Python

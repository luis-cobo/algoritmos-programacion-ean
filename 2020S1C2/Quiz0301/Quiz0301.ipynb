# %% [markdown]
# <h1 align="center">Quiz 03 - Funciones en Python</h1>
#
# Nombre Completo Estudiante:

# %% [markdown]
# ---
#
# # Ejercicio 1:
#
# Escriba el modelaje y una función en Python que halle el área de un rectángulo a partir de su base y altura

# %% [markdown]
# ## Modelaje
#
# _Datos de Entrada_
#
# Nombre | Identificador | Tipo
# -------| --------------|------
#
# _Datos de Salida_
#
# Nombre | Identificador | Tipo
# -------| --------------|------

# %%
# Escriba aquí la función en Python

# %% [markdown]
# ---
#
# # Ejercicio 2
#
# Escriba el modelaje y la función en Python que encuentre el área de un círculo. Acuérdense que el área del círculo se encuentra a partir de la siguiente fórmula: $A = \pi \cdot r^2$.

# %% [markdown]
# ## Modelaje
#
# _Datos de Entrada_
#
# Nombre | Identificador | Tipo
# -------| --------------|------
#
# _Datos de Salida_
#
# Nombre | Identificador | Tipo
# -------| --------------|------

# %%
# Escriba aquí la función en Python

# %% [markdown]
# ---
#
# # Ejercicio 3
#
# Escriba el modelaje y la función en Python que halle el cateto de un triángulo rectángulo, conociendo la hipotenusa y el otro cateto. Por ejemplo, la siguiente figura nos muestra un triángulo rectángulo con sus catetos y la hipotenusa.
#
# ![Hipotenusa](https://content.nroc.org/DevelopmentalMath.HTML5/U07L1T4/TopicText/es/U07_L1_T4_text_final_files_es/image001.gif)
#
# La fórmula para encontrar el cateto es: $a = \sqrt{c^2 - b^2}$.

# %% [markdown]
# ## Modelaje
#
# _Datos de Entrada_
#
# Nombre | Identificador | Tipo
# -------| --------------|------
#
# _Datos de Salida_
#
# Nombre | Identificador | Tipo
# -------| --------------|------

# %%
# Escriba la función en Python aquí

# %% [markdown]
# ---
#
# # Ejercicio 4
#
# Escriba el modelaje y la función en Python que halle el área de la siguiente figura compleja, a partir de los valores de $x$, $y$ y $z$. **OJO: OBLIGATORIO EL USO DE LAS FUNCIONES ANTERIORES** No de papaya.
#
# ![Figura 04](https://github.com/luis-cobo/algoritmos-programacion-ean/raw/master/imagenes/quiz03fig01.png)

# %% [markdown]
# ## Modelaje
#
# _Datos de Entrada_
#
# Nombre | Identificador | Tipo
# -------| --------------|------
#
# _Datos de Salida_
#
# Nombre | Identificador | Tipo
# -------| --------------|------

# %%
# Escriba la función en Python aquí
